# %%
# !pip install --upgrade segments-ai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 1.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Obtaining dependency information for pydantic!=2.4.0,==2.* from https://files.pythonhosted.org/packages/df/e4/ba44652d562cbf0bf320e0f3810206149c8a4e99cdbf66da82e97ab53a15/pydantic-2.9.2-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.4/149.4 kB 5.3 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for types-Pillow>=9.0 from https://files.pythonhosted.org/packages/66/23/e81a5354859831fcf54d488d33b80ba6133ea84f874a9c0ec40a4881e133/types_Pillow-10.2.0.20240822-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for types-requests==2.* from https://files.pythonhosted.org/packages/8f/55/ea44dad71b9d92f86198f7448f5ba46ac919355f4f69bb1c0fa1af02b1b4/types_requests-2.32.0.20240914-py3-none-any.whl.metadata
# ...

# %%
# !pip install -U "huggingface_hub[cli]"
# Out:
# ...
#   Obtaining dependency information for huggingface_hub[cli] from https://files.pythonhosted.org/packages/5f/f1/15dc793cb109a801346f910a6b350530f2a763a6e83b221725a0bcc1e297/huggingface_hub-0.25.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for InquirerPy==0.3.4 from https://files.pythonhosted.org/packages/ce/ff/3b59672c47c6284e8005b42e84ceba13864aa0f39f067c973d1af02f5d91/InquirerPy-0.3.4-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for pfzy<0.4.0,>=0.3.1 from https://files.pythonhosted.org/packages/8c/d7/8ff98376b1acc4503253b685ea09981697385ce344d4e3935c2af49e044d/pfzy-0.3.4-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.4/436.4 kB 8.6 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.23.2
#     Uninstalling huggingface-hub-0.23.2:
# ...

# %%
# let us first install relavant libraries from HF
# make sure that we are using the latest libraries which support logging-in via tokens
# install or simple upgrade to latest version (upgrade needed on kaggle notebook)
# for kaggle notebook, you may need to restart runtime to load the upgraded libraries correctly
# !pip install --upgrade huggingface-hub
# !pip install --upgrade transformers
# Out:
# ...
#   Obtaining dependency information for huggingface-hub from https://files.pythonhosted.org/packages/5f/f1/15dc793cb109a801346f910a6b350530f2a763a6e83b221725a0bcc1e297/huggingface_hub-0.25.1-py3-none-any.whl.metadata
#   Using cached huggingface_hub-0.25.1-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached huggingface_hub-0.25.1-py3-none-any.whl (436 kB)
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 0.23.1
#     Uninstalling huggingface_hub-0.23.1:
#       Successfully uninstalled huggingface_hub-0.23.1
# ...
#   Obtaining dependency information for transformers from https://files.pythonhosted.org/packages/f9/9d/030cc1b3e88172967e22ee1d012e0d5e0384eb70d2a098d1669d549aea29/transformers-4.45.2-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.4 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade accelerate
# Out:
# ...
#   Obtaining dependency information for accelerate from https://files.pythonhosted.org/packages/2a/7c/6daed4be624f903643edd1b91670ce321a4cf08afd2b96ac368461742e89/accelerate-1.0.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for safetensors>=0.4.3 from https://files.pythonhosted.org/packages/08/8c/ece3bf8756506a890bd980eca02f47f9d98dfbf5ce16eda1368f53560f67/safetensors-0.4.5-cp311-cp311-macosx_11_0_arm64.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.9/330.9 kB 5.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.5/381.5 kB 9.8 MB/s eta 0:00:00:00:01
# ...
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.4.2
#     Uninstalling safetensors-0.4.2:
#       Successfully uninstalled safetensors-0.4.2
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.33.0
#     Uninstalling accelerate-0.33.0:
#       Successfully uninstalled accelerate-0.33.0
# ...

# %%
# %pip install fsspec==2021.10
# Out:
# ...
#   Obtaining dependency information for fsspec==2021.10 from https://files.pythonhosted.org/packages/8a/14/1cd46db2f2f8b7fb9abc53c06af5d69cbb69a55b46bccc779d24394b5cb3/fsspec-2021.10.0-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.0/125.0 kB 2.4 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.6.0
#     Uninstalling fsspec-2024.6.0:
#       Successfully uninstalled fsspec-2024.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 2.12.0 requires fsspec[http]>=2021.11.1, but you have fsspec 2021.10.0 which is incompatible.
# huggingface-hub 0.25.1 requires fsspec>=2023.5.0, but you have fsspec 2021.10.0 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install s3fs==2021.10
# Out:
# ...
#   Obtaining dependency information for s3fs==2021.10 from https://files.pythonhosted.org/packages/00/f2/009dcb95736486c85eb4ce8c071584317d795836611d51f4c398645785d3/s3fs-2021.10.0-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Obtaining dependency information for botocore<1.20.107,>=1.20.106 from https://files.pythonhosted.org/packages/9a/14/3e13e2db6a8f2690d53d202baa1390d0c0141c9577d5c7fca751fea40c5e/botocore-1.20.106-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for jmespath<1.0.0,>=0.7.1 from https://files.pythonhosted.org/packages/07/cb/5f001272b6faeb23c1c9e0acc04d48eaaf5c862c17709d20e3469c6e0139/jmespath-0.10.0-py2.py3-none-any.whl.metadata
# ...

# %%
# !pip install evaluate
# Out:
# ...
#   Obtaining dependency information for evaluate from https://files.pythonhosted.org/packages/a2/e7/cbca9e2d2590eb9b5aa8f7ebabe1beb1498f9462d2ecede5c9fd9735faaf/evaluate-0.4.3-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for fsspec[http]>=2021.05.0 from https://files.pythonhosted.org/packages/1d/a0/6aaea0c2fbea2f89bfd5db25fb1e3481896a423002ebe4e55288907a97a3/fsspec-2024.9.0-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 696.0 kB/s eta 0:00:000:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 5.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2021.10.0
#     Uninstalling fsspec-2021.10.0:
#       Successfully uninstalled fsspec-2021.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !pip install -U evaluate

# %%
import scipy.io
import math
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
from skimage.transform import resize
import torch.nn as nn
import torch
from torchsummary import summary
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader, random_split  # For custom data-sets
from torch.nn.functional import relu
from PIL import Image
import random
from transformers import AutoImageProcessor, SegformerForSemanticSegmentation, TrainingArguments, Trainer, SegformerFeatureExtractor
from datasets import Dataset, DatasetDict, Image, Features
import glob
import huggingface_hub
import json
from huggingface_hub import hf_hub_download
from torchvision.transforms import ColorJitter
from transformers import SegformerImageProcessor
import torch
from torch import nn
import evaluate

# %matplotlib inline
# Out:
# /Users/sneha/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
pwd
# Out:
# '/Users/sneha/Downloads'

# %%
IMAGES = glob.glob("/Users/sneha/Downloads/segmentation_new/images/*.JPG")
SEG_MAPS = glob.glob("/Users/sneha/Downloads/segmentation_new/masks/*.png") 
dataset = Dataset.from_dict({"image": IMAGES, "label": SEG_MAPS}, features=Features({"image": Image(), "label": Image()}))

# %%
huggingface_hub.login('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')
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /Users/sneha/.cache/huggingface/token
# Login successful

# %%
# !pip install -U datasets huggingface-hub
# Out:
# ...
#   Obtaining dependency information for datasets from https://files.pythonhosted.org/packages/be/3e/e58d4db4cfe71e3ed07d169af24db30cfd582e16f977378bd43fd7ec1998/datasets-3.0.1-py3-none-any.whl.metadata
#   Using cached datasets-3.0.1-py3-none-any.whl.metadata (20 kB)
# ...
#   Obtaining dependency information for huggingface-hub from https://files.pythonhosted.org/packages/64/09/a535946bf2dc88e61341f39dc507530411bb3ea4eac493e5ec833e8f35bd/huggingface_hub-0.25.2-py3-none-any.whl.metadata
# ...
# Using cached datasets-3.0.1-py3-none-any.whl (471 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.6/436.6 kB 5.8 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.25.1
#     Uninstalling huggingface-hub-0.25.1:
#       Successfully uninstalled huggingface-hub-0.25.1
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.10.0
#     Uninstalling datasets-2.10.0:
# ...

# %%
# step 3: push to hub (assumes you have ran the huggingface-cli login command in a terminal/notebook)
hf_username, dataset_name = 'srao0996', 'sealants-images'
hf_dataset_identifier = f"{hf_username}/{dataset_name}"

dataset.push_to_hub(hf_dataset_identifier)
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# No files have been modified since last commit. Skipping to prevent empty commit.
# CommitInfo(commit_url='https://huggingface.co/datasets/srao0996/sealants-images/commit/9e151f2dfd3b43289b20fac0b67dbeee91f731b4', commit_message='Upload dataset', commit_description='', oid='9e151f2dfd3b43289b20fac0b67dbeee91f731b4', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/srao0996/sealants-images', endpoint='https://huggingface.co', repo_type='dataset', repo_id='srao0996/sealants-images'), pr_revision=None, pr_num=None)

# %%
from datasets import load_dataset

ds = load_dataset(hf_dataset_identifier)

# %%
def transforms(examples):
    examples["pixel_values"] = [image.convert("RGB").resize((512,512)) for image in examples["image"]]
    return examples

ds = ds.map(transforms, remove_columns=["image"], batched=True)

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'pixel_values'],
#         num_rows: 32
#     })
# })

# %%
ds = ds.shuffle(seed=1)
ds = ds["train"].train_test_split(test_size=0.1)
train_ds = ds["train"]
test_ds = ds["test"]

# %%
train_ds
# Out:
# Dataset({
#     features: ['label', 'pixel_values'],
#     num_rows: 28
# })

# %%
id2label = {0:'background', 1: 'sealant'}
with open('id2label.json', 'w') as fp:
    json.dump(id2label, fp)

# %%
repo_id = f"datasets/{hf_dataset_identifier}"
filename = "id2label.json"
id2label = json.load(open(hf_hub_download(repo_id=hf_dataset_identifier, filename=filename, repo_type="dataset"), "r"))
print(id2label.items())
id2label = {int(k): v for k, v in id2label.items()}
label2id = {v: k for k, v in id2label.items()}

num_labels = len(id2label)
# Out:
# id2label.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# dict_items([('0', 'unlabeled'), ('255', 'sealant')])

# %%
print(num_labels)
print(id2label)
print(label2id)
# Out:
# 2
# {0: 'unlabeled', 255: 'sealant'}
# {'unlabeled': 0, 'sealant': 255}

# %%
# use the ColorJitter function from torchvision to randomly change the brightness, contrast, saturation, and hue of the images in the batch
# define data augmentations to make our model more resilient to different lightning conditions 
processor = SegformerImageProcessor()
jitter = ColorJitter(brightness=0.25, contrast=0.25, saturation=0.25, hue=0.1) 

def train_transforms(example_batch):
    images = [jitter(x) for x in example_batch['pixel_values']]
    labels = [x for x in example_batch['label']]
    inputs = processor(images, labels)
    print('++', inputs)
    return inputs

def val_transforms(example_batch):
    images = [x for x in example_batch['pixel_values']]
    labels = [x for x in example_batch['label']]
    inputs = processor(images, labels)
    return inputs

# Set transforms
train_ds.set_transform(train_transforms)
test_ds.set_transform(val_transforms)

# %%
# SegFormer authors define 5 models with increasing sizes: B0 to B5
from transformers import SegformerForSemanticSegmentation

pretrained_model_name = "nvidia/mit-b0" 
model = SegformerForSemanticSegmentation.from_pretrained(
    pretrained_model_name,
    id2label=id2label,
    label2id=label2id,
    num_labels = 2, 
    ignore_mismatched_sizes = True
)
# Out:
# Some weights of SegformerForSemanticSegmentation were not initialized from the model checkpoint at nvidia/mit-b0 and are newly initialized: ['decode_head.batch_norm.bias', 'decode_head.batch_norm.num_batches_tracked', 'decode_head.batch_norm.running_mean', 'decode_head.batch_norm.running_var', 'decode_head.batch_norm.weight', 'decode_head.classifier.bias', 'decode_head.classifier.weight', 'decode_head.linear_c.0.proj.bias', 'decode_head.linear_c.0.proj.weight', 'decode_head.linear_c.1.proj.bias', 'decode_head.linear_c.1.proj.weight', 'decode_head.linear_c.2.proj.bias', 'decode_head.linear_c.2.proj.weight', 'decode_head.linear_c.3.proj.bias', 'decode_head.linear_c.3.proj.weight', 'decode_head.linear_fuse.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
epochs = 50
lr = 0.00006
batch_size = 2

hub_model_id = "segformer-b0-finetuned-segments-sealants-2"

training_args = TrainingArguments(
    "segformer-b0-finetuned-segments-sealants-outputs",
    learning_rate=lr,
    num_train_epochs=epochs,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    save_total_limit=3,
    eval_strategy="steps",
    save_strategy="steps",
    save_steps=20,
    eval_steps=20,
    logging_steps=1,
    eval_accumulation_steps=5,
    load_best_model_at_end=True,
    push_to_hub=True,
    hub_model_id=hub_model_id,
    hub_strategy="end",
)

# %%
# !pip install datasets==2.10.0
# Out:
# ...
#   Obtaining dependency information for datasets==2.10.0 from https://files.pythonhosted.org/packages/0c/a1/a615deaa59fbdec753dfabc3f074d5803e4a8aa15db9a40578bb9c35e787/datasets-2.10.0-py3-none-any.whl.metadata
#   Using cached datasets-2.10.0-py3-none-any.whl.metadata (20 kB)
# ...
# Using cached datasets-2.10.0-py3-none-any.whl (469 kB)
# ...
#   Attempting uninstall: datasets
#     Found existing installation: datasets 3.0.1
#     Uninstalling datasets-3.0.1:
#       Successfully uninstalled datasets-3.0.1
# ...

# %%
metric = evaluate.load("mean_iou")

def compute_metrics(eval_pred):
    with torch.no_grad():
        logits, labels = eval_pred
        logits_tensor = torch.from_numpy(logits)
        # scale the logits to the size of the label
        logits_tensor = nn.functional.interpolate(
            logits_tensor,
            size=labels.shape[-2:],
            mode="bilinear",
            align_corners=False,
        ).argmax(dim=1)
        
        pred_labels = logits_tensor.detach().cpu().numpy()
        metrics = metric.compute(
            predictions=pred_labels,
            references=labels,
            num_labels=len(id2label),
            ignore_index=0,
            reduce_labels=processor.do_reduce_labels,
        )
        
        # add per category metrics as individual key-value pairs
        per_category_accuracy = metrics.pop("per_category_accuracy").tolist()
        per_category_iou = metrics.pop("per_category_iou").tolist()
        
        print('+++', per_category_iou)
        metrics.update({f"accuracy_{id2label[i]}": v for i, v in enumerate(per_category_accuracy)})
        metrics.update({f"iou_{id2label[i]}": v for i, v in enumerate(per_category_iou)})
        
        return metrics

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_ds,
    eval_dataset=test_ds,
    compute_metrics=compute_metrics,
)

# %%
trainer.train()
# Out:
# ++ {'pixel_values': [array([[[-0.19993155, -0.19993155, -0.2170563 , ...,  0.1939379 ,
#           0.17681314,  0.1939379 ],
#         [-0.19993155, -0.13143253, -0.08005828, ...,  0.1939379 ,
#           0.21106265,  0.24531215],
#         [-0.16568205, -0.13143253, -0.08005828, ...,  0.21106265,
#           0.21106265,  0.2281874 ],
#         ...,
#         [-0.2855553 , -0.25130582, -0.19993155, ..., -0.18280679,
#          -0.2170563 , -0.26843056],
#         [-0.19993155, -0.25130582, -0.25130582, ..., -0.16568205,
#          -0.18280679, -0.18280679],
#         [-0.2170563 , -0.26843056, -0.2170563 , ..., -0.14855729,
#          -0.23418105, -0.23418105]],
#
#        [[-0.05742295, -0.02240895, -0.07492995, ...,  0.3627452 ,
#           0.3277312 ,  0.3452382 ],
#         [-0.05742295,  0.03011205,  0.03011205, ...,  0.3452382 ,
#           0.3452382 ,  0.3977592 ],
#         [-0.02240895,  0.01260505,  0.03011205, ...,  0.3452382 ,
#           0.3802522 ,  0.3802522 ],
# ...

# %%
kwargs = {
    "tags": ["vision", "image-segmentation"],
    "finetuned_from": pretrained_model_name,
    "dataset": hf_dataset_identifier,
}

processor.push_to_hub(hub_model_id)
trainer.push_to_hub(**kwargs)
